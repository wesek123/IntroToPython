# %% [markdown]
# # Exam
#
# During the exam we will analyze League of Legends match data. You will have 10 tasks to complete over `2` hours. You can use any resources you need (internet, notes, documentation), but you must complete the task alone - violation will be severly punished. To pass you need `60%` correct answers. You need to post the exam in your repository until `17:15`. If you post your answers after `17:15`, you won't be graded based on your repository notebook work and will receive a grade of `2`.
#
# ### Grading
#
# | Points | Grade |
# | :-- | :-- |
# | 6 | 3 |
# | 7 | 3.5 |
# | 8 | 4 |
# | 9 | 4.5 |
# | 10 | 5 |
#
# Each task can get between `0` and `1` points. So, if you do only a couple of things correct you can get eg. `0.6` points.

# %%
# Your student id here
student_id = 141035

# %%
# Import libraries you will use here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set seaborn coloring

# %% [markdown]
# ## Task 1
#
# `[0.4]` Import the csv file `high_diamond_ranked_10min.csv` to a variable `lol_data`. Set the index column to `gameId`.

# %%
# Your code here
lol_data = pd.read_csv("high_diamond_ranked_10min.csv", index_col='gameId')

# %% [markdown]
# `[0.2]` Display random 10 rows from the dataset.

# %%
# Your code here
lol_data.sample(10)
# Out:
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4527530188         1               99                   7               1
# 4524110417         0               16                   5               1
# 4508799837         1               16                   1               0
# 4513297103         0               14                   2               0
# 4508101367         1               14                   2               0
# 4507906686         0               12                   3               0
# 4511234219         0               13                   1               0
# 4524478226         1               15                   2               0
# 4511067613         0               15                   6               0
# 4519628071         0               13                   1               0
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# gameId
# 4527530188          6           7            7                  1
# 4524110417          9           6            5                  0
# 4508799837          6           4            6                  1
# 4513297103          4          14            4                  1
# 4508101367          6           4            5                  0
# 4507906686          3           9            0                  0
# 4511234219          4           9            8                  0
# 4524478226         12          10           20                  0
# 4511067613          8           7            9                  1
# 4519628071          1           7            1                  1
#
#             blueDragons  blueHeralds  ...  redTowersDestroyed  redTotalGold  \
# gameId                                ...
# 4527530188            1            0  ...                   0         16616
# 4524110417            0            0  ...                   0         16075
# 4508799837            0            1  ...                   0         15462
# 4513297103            0            1  ...                   1         22088
# 4508101367            0            0  ...                   0         15107
# 4507906686            0            0  ...                   0         17543
# 4511234219            0            0  ...                   0         18834
# 4524478226            0            0  ...                   0         17483
# 4511067613            1            0  ...                   0         16648
# 4519628071            0            1  ...                   0         16696
#
#             redAvgLevel  redTotalExperience  redTotalMinionsKilled  \
# gameId
# 4527530188          6.8               17183                    228
# 4524110417          7.0               17851                    193
# 4508799837          7.0               18117                    230
# 4513297103          7.4               19489                    218
# 4508101367          6.6               17034                    216
# 4507906686          7.0               18875                    223
# 4511234219          7.4               19794                    236
# 4524478226          6.8               18108                    159
# 4511067613          6.6               16874                    211
# 4519628071          7.0               18381                    220
#
#             redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  \
# gameId
# 4527530188                           47         -577              -1371
# 4524110417                           52        -1266              -1770
# 4508799837                           46        -3163              -1231
# 4513297103                           56         7480               4460
# 4508101367                           48        -1530              -2305
# 4507906686                           50         3041               1317
# 4511234219                           56         1763               2184
# 4524478226                           75         -478                124
# 4511067613                           43         -515              -1691
# 4519628071                           47         2955               2776
#
#             redCSPerMin  redGoldPerMin
# gameId
# 4527530188         22.8         1661.6
# 4524110417         19.3         1607.5
# 4508799837         23.0         1546.2
# 4513297103         21.8         2208.8
# 4508101367         21.6         1510.7
# 4507906686         22.3         1754.3
# 4511234219         23.6         1883.4
# 4524478226         15.9         1748.3
# 4511067613         21.1         1664.8
# 4519628071         22.0         1669.6
#
# [10 rows x 39 columns]

# %% [markdown]
# `[0.2]` Display the information about the dataset - columns, dtypes, etc.

# %%
# Your code here
lol_data.dtypes
#or
#lol_data.info()
# Out:
# blueWins                          int64
# blueWardsPlaced                   int64
# blueWardsDestroyed                int64
# blueFirstBlood                    int64
# blueKills                         int64
# blueDeaths                        int64
# blueAssists                       int64
# blueEliteMonsters                 int64
# blueDragons                       int64
# blueHeralds                       int64
# blueTowersDestroyed               int64
# blueTotalGold                     int64
# blueAvgLevel                    float64
# blueTotalExperience               int64
# blueTotalMinionsKilled            int64
# blueTotalJungleMinionsKilled      int64
# blueGoldDiff                      int64
# blueExperienceDiff                int64
# blueCSPerMin                    float64
# blueGoldPerMin                  float64
# redWardsPlaced                    int64
# redWardsDestroyed                 int64
# redFirstBlood                     int64
# redKills                          int64
# redDeaths                         int64
# redAssists                        int64
# redEliteMonsters                  int64
# redDragons                        int64
# redHeralds                        int64
# redTowersDestroyed                int64
# redTotalGold                      int64
# redAvgLevel                     float64
# redTotalExperience                int64
# redTotalMinionsKilled             int64
# redTotalJungleMinionsKilled       int64
# redGoldDiff                       int64
# redExperienceDiff                 int64
# redCSPerMin                     float64
# redGoldPerMin                   float64
# dtype: object

# %% [markdown]
# `[0.2]` Display statistical information about the dataset - mean, quartiles, etc.

# %%
# Your code here
lol_data.describe()
# Out:
#           blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# count  9879.000000      9879.000000         9879.000000     9879.000000
# mean      0.499038        22.288288            2.824881        0.504808
# std       0.500024        18.019177            2.174998        0.500002
# min       0.000000         5.000000            0.000000        0.000000
# 25%       0.000000        14.000000            1.000000        0.000000
# 50%       0.000000        16.000000            3.000000        1.000000
# 75%       1.000000        20.000000            4.000000        1.000000
# max       1.000000       250.000000           27.000000        1.000000
#
#          blueKills   blueDeaths  blueAssists  blueEliteMonsters  blueDragons  \
# count  9879.000000  9879.000000  9879.000000        9879.000000  9879.000000
# mean      6.183925     6.137666     6.645106           0.549954     0.361980
# std       3.011028     2.933818     4.064520           0.625527     0.480597
# min       0.000000     0.000000     0.000000           0.000000     0.000000
# 25%       4.000000     4.000000     4.000000           0.000000     0.000000
# 50%       6.000000     6.000000     6.000000           0.000000     0.000000
# 75%       8.000000     8.000000     9.000000           1.000000     1.000000
# max      22.000000    22.000000    29.000000           2.000000     1.000000
#
#        blueHeralds  ...  redTowersDestroyed  redTotalGold  redAvgLevel  \
# count  9879.000000  ...         9879.000000   9879.000000  9879.000000
# mean      0.187974  ...            0.043021  16489.041401     6.925316
# std       0.390712  ...            0.216900   1490.888406     0.305311
# min       0.000000  ...            0.000000  11212.000000     4.800000
# 25%       0.000000  ...            0.000000  15427.500000     6.800000
# 50%       0.000000  ...            0.000000  16378.000000     7.000000
# 75%       0.000000  ...            0.000000  17418.500000     7.200000
# max       1.000000  ...            2.000000  22732.000000     8.200000
#
#        redTotalExperience  redTotalMinionsKilled  redTotalJungleMinionsKilled  \
# count         9879.000000            9879.000000                  9879.000000
# mean         17961.730438             217.349226                    51.313088
# std           1198.583912              21.911668                    10.027885
# min          10465.000000             107.000000                     4.000000
# 25%          17209.500000             203.000000                    44.000000
# 50%          17974.000000             218.000000                    51.000000
# 75%          18764.500000             233.000000                    57.000000
# max          22269.000000             289.000000                    92.000000
#
#         redGoldDiff  redExperienceDiff  redCSPerMin  redGoldPerMin
# count   9879.000000        9879.000000  9879.000000    9879.000000
# mean     -14.414111          33.620306    21.734923    1648.904140
# std     2453.349179        1920.370438     2.191167     149.088841
# min   -11467.000000       -8348.000000    10.700000    1121.200000
# 25%    -1596.000000       -1212.000000    20.300000    1542.750000
# 50%      -14.000000          28.000000    21.800000    1637.800000
# 75%     1585.500000        1290.500000    23.300000    1741.850000
# max    10830.000000        9333.000000    28.900000    2273.200000
#
# [8 rows x 39 columns]

# %% [markdown]
# ## Task 2
#
# `[0.2]` Create a new column `whoWon` which contains `"red"` or `"blue"` based on the `blueWins` column.

# %%
# Your code here
def addCol1(row):
    if(row.blueWins==0):
        return "red"
    else:
        return "blue"
whoWon=lol_data.apply(addCol1,axis="columns")
lol_data['whoWon']=whoWon
lol_data.sample(10)
# Out:
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4479811257         1               26                   4               0
# 4484417350         0               15                   1               0
# 4509340231         0               14                   0               0
# 4447426572         1               17                   3               0
# 4492812373         1               22                   5               0
# 4510326831         1               15                   5               1
# 4524960407         1               22                   0               1
# 4494291659         0               13                   0               1
# 4483650027         0               17                   3               0
# 4514071420         1               13                   3               1
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# gameId
# 4479811257          5          10            8                  0
# 4484417350          2           8            3                  0
# 4509340231          8          11            9                  1
# 4447426572          8           6            7                  1
# 4492812373          3           2            1                  1
# 4510326831          3           5            3                  0
# 4524960407          4           7            4                  1
# 4494291659          1           7            2                  0
# 4483650027          1           6            1                  0
# 4514071420         12           8           18                  1
#
#             blueDragons  blueHeralds  ...  redTotalGold  redAvgLevel  \
# gameId                                ...
# 4479811257            0            0  ...         19441          7.2
# 4484417350            0            0  ...         17648          7.2
# 4509340231            1            0  ...         19051          7.2
# 4447426572            1            0  ...         16312          7.0
# 4492812373            0            1  ...         13567          6.6
# 4510326831            0            0  ...         16296          7.4
# 4524960407            0            1  ...         17773          6.8
# 4494291659            0            0  ...         16620          7.2
# 4483650027            0            0  ...         16212          7.2
# 4514071420            1            0  ...         17368          7.0
#
#             redTotalExperience  redTotalMinionsKilled  \
# gameId
# 4479811257               18189                    230
# 4484417350               18469                    243
# 4509340231               18726                    228
# 4447426572               17570                    206
# 4492812373               15702                    169
# 4510326831               19295                    251
# 4524960407               17577                    209
# 4494291659               18936                    247
# 4483650027               18019                    228
# 4514071420               18376                    206
#
#             redTotalJungleMinionsKilled  redGoldDiff  redExperienceDiff  \
# gameId
# 4479811257                           51         3731               1458
# 4484417350                           43         3215               1656
# 4509340231                           40         2339                917
# 4447426572                           52         -819              -2149
# 4492812373                           60        -2679              -3685
# 4510326831                           58         1161               1685
# 4524960407                           46          669                502
# 4494291659                           44         3521               4416
# 4483650027                           52         1887                587
# 4514071420                           44         -679                305
#
#             redCSPerMin  redGoldPerMin  whoWon
# gameId
# 4479811257         23.0         1944.1    blue
# 4484417350         24.3         1764.8     red
# 4509340231         22.8         1905.1     red
# 4447426572         20.6         1631.2    blue
# 4492812373         16.9         1356.7    blue
# 4510326831         25.1         1629.6    blue
# 4524960407         20.9         1777.3    blue
# 4494291659         24.7         1662.0     red
# 4483650027         22.8         1621.2     red
# 4514071420         20.6         1736.8    blue
#
# [10 rows x 40 columns]

# %% [markdown]
# `[0.2]` Create a new column `firstKill` which contains `"red"` or `"blue"` based on either `blueFirstBlood` or `redFirstBlood`.

# %%
# Your code here
def addCol2(row):
    if(row.blueFirstBlood):
        return "blue"
    if(row.redFirstBlood):
        return "red"
firstKill=lol_data.apply(addCol2,axis="columns")
lol_data['firstKill']=firstKill
lol_data.sample(10)
# Out:
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4450237694         1               19                   5               1
# 4489642674         1               38                   4               1
# 4468771669         0               19                   3               1
# 4516851869         0               13                   3               1
# 4523806896         0               19                   0               0
# 4455594728         1               26                   5               0
# 4524469439         1               16                   2               1
# 4296004784         1               19                   5               1
# 4524074861         0               15                   0               1
# 4521042540         1               14                   2               1
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# gameId
# 4450237694          8           9            9                  0
# 4489642674          6           5            6                  1
# 4468771669          4           9            4                  1
# 4516851869          2           9            0                  1
# 4523806896          3           8            4                  0
# 4455594728          3           5            2                  0
# 4524469439          8          10            7                  1
# 4296004784          6           2            6                  1
# 4524074861          7           9            6                  0
# 4521042540          8           7            7                  1
#
#             blueDragons  blueHeralds  ...  redAvgLevel  redTotalExperience  \
# gameId                                ...
# 4450237694            0            0  ...          7.0               18954
# 4489642674            1            0  ...          7.0               18295
# 4468771669            0            1  ...          7.0               18702
# 4516851869            1            0  ...          7.4               20529
# 4523806896            0            0  ...          6.8               17756
# 4455594728            0            0  ...          7.0               17813
# 4524469439            1            0  ...          7.2               18731
# 4296004784            1            0  ...          6.4               16517
# 4524074861            0            0  ...          7.0               18263
# 4521042540            1            0  ...          7.2               19508
#
#             redTotalMinionsKilled  redTotalJungleMinionsKilled  redGoldDiff  \
# gameId
# 4450237694                    202                           60        -1334
# 4489642674                    224                           62          282
# 4468771669                    243                           40         2316
# 4516851869                    236                           72         4410
# 4523806896                    213                           64         2247
# 4455594728                    240                           44          531
# 4524469439                    210                           35         1147
# 4296004784                    232                           44        -2944
# 4524074861                    211                           60         1923
# 4521042540                    204                           52         -938
#
#             redExperienceDiff  redCSPerMin  redGoldPerMin  whoWon  firstKill
# gameId
# 4450237694               -656         20.2         1719.5    blue       blue
# 4489642674                192         22.4         1638.0    blue       blue
# 4468771669               2043         24.3         1794.4     red       blue
# 4516851869               4163         23.6         1821.3     red       blue
# 4523806896               1501         21.3         1670.9     red        red
# 4455594728                -28         24.0         1575.2    blue        red
# 4524469439               1294         21.0         1772.3    blue       blue
# 4296004784              -3092         23.2         1441.0    blue       blue
# 4524074861               1753         21.1         1799.3     red       blue
# 4521042540               -181         20.4         1733.3    blue       blue
#
# [10 rows x 41 columns]

# %% [markdown]
# `[0.1]` Set the dtype of the `whoWon` and `firstKill` to categorical.

# %%
# Your code here
lol_data.firstKill = lol_data.firstKill.astype('category')
lol_data.whoWon = lol_data.whoWon.astype('category')
lol_data.firstKill
lol_data.whoWon
# Out:
# gameId
# 4519157822     red
# 4523371949     red
# 4521474530     red
# 4524384067     red
# 4436033771     red
#               ...
# 4527873286    blue
# 4527797466    blue
# 4527713716     red
# 4527628313     red
# 4523772935    blue
# Name: whoWon, Length: 9879, dtype: category
# Categories (2, object): [blue, red]

# %% [markdown]
# `[0.5]` Cast all `float` columns to `int`, while setting each value to its ceiling.

# %%
# Your code here
def changeCasting(column):
    if(column.dtype == "float64"):
        column = column.astype("int64")
    print(column.dtype)
    #additionally it shows that task above is completed :)
showDtype=lol_data.apply(changeCasting, axis="rows")
# Out:
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# int64
# category
# category

# %% [markdown]
# ## Task 3
#
# `[1.0]` Create two new columns: `blueFinalWards` and `redFinalWards` that are calculated in the following manner:
#
# ```
# blueFinalWards = blueWardsPlaced - redWardsDestroyed
# redFinalWards = redWardsPlaced - blueWardsDestroyed
# ```

# %%
# Your code here
lol_data['blueFinalWards'] = lol_data.apply(lambda x: x['blueWardsPlaced'] - x['redWardsDestroyed'], axis = 1)
lol_data['redFinalWards'] = lol_data.apply(lambda x: x['redWardsPlaced'] - x['blueWardsDestroyed'], axis = 1)

# %% [markdown]
# ## Task 4
#
# `[0.5]` Create two new columns: `blueMinionsKilledOutsideJungle` and `redMinionsKilledOutsideJungle` which is a difference of two specific columns in the dataset and save it to the variable `lol_data_updated`.

# %%
# Your code here
lol_data['blueMinionsKilledOutsideJungle'] = lol_data.apply(lambda x: x['blueTotalMinionsKilled'] - x['blueTotalJungleMinionsKilled'], axis = 1)
lol_data['redMinionsKilledOutsideJungle'] = lol_data.apply(lambda x: x['redTotalMinionsKilled'] - x['redTotalJungleMinionsKilled'], axis = 1)
lol_data_updated = lol_data.loc[:,['blueMinionsKilledOutsideJungle', 'redMinionsKilledOutsideJungle']]

# %% [markdown]
# `[0.5]` Remove the following columns: `blueTotalMinionsKilled`, `redTotalMinionsKilled`, `blueTotalJungleMinionsKilled`, `redTotalJungleMinionsKilled` and save this to the previous variable.

# %%
# Your code here
lol_data_update = lol_data.loc[:,['blueMinionsKilledOutsideJungle', 'redMinionsKilledOutsideJungle', 'blueTotalMinionsKilled', 'redTotalMinionsKilled', 'blueTotalJungleMinionsKilled', 'redTotalJungleMinionsKilled' ]]
lol_data.drop(columns={"blueTotalMinionsKilled", "redTotalMinionsKilled", "blueTotalJungleMinionsKilled", "redTotalJungleMinionsKilled"})
# Out:
#             blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# gameId
# 4519157822         0               28                   2               1
# 4523371949         0               12                   1               0
# 4521474530         0               15                   0               0
# 4524384067         0               43                   1               0
# 4436033771         0               75                   4               0
# ...              ...              ...                 ...             ...
# 4527873286         1               17                   2               1
# 4527797466         1               54                   0               0
# 4527713716         0               23                   1               0
# 4527628313         0               14                   4               1
# 4523772935         1               18                   0               1
#
#             blueKills  blueDeaths  blueAssists  blueEliteMonsters  \
# gameId
# 4519157822          9           6           11                  0
# 4523371949          5           5            5                  0
# 4521474530          7          11            4                  1
# 4524384067          4           5            5                  1
# 4436033771          6           6            6                  0
# ...               ...         ...          ...                ...
# 4527873286          7           4            5                  1
# 4527797466          6           4            8                  1
# 4527713716          6           7            5                  0
# 4527628313          2           3            3                  1
# 4523772935          6           6            5                  0
#
#             blueDragons  blueHeralds  ...  redGoldDiff  redExperienceDiff  \
# gameId                                ...
# 4519157822            0            0  ...         -643                  8
# 4523371949            0            0  ...         2908               1173
# 4521474530            1            0  ...         1172               1033
# 4524384067            0            1  ...         1321                  7
# 4436033771            0            0  ...         1004               -230
# ...                 ...          ...  ...          ...                ...
# 4527873286            1            0  ...        -2519              -2469
# 4527797466            1            0  ...         -782               -888
# 4527713716            0            0  ...         2416               1877
# 4527628313            1            0  ...          839               1085
# 4523772935            0            0  ...         -927                 58
#
#             redCSPerMin  redGoldPerMin  whoWon  firstKill  blueFinalWards  \
# gameId
# 4519157822         19.7         1656.7     red       blue              22
# 4523371949         24.0         1762.0     red        red              11
# 4521474530         20.3         1728.5     red        red              12
# 4524384067         23.5         1647.8     red        red              41
# 4436033771         22.5         1740.4     red        red              73
# ...                 ...            ...     ...        ...             ...
# 4527873286         22.9         1524.6    blue       blue              14
# 4527797466         20.6         1545.6    blue        red              33
# 4527713716         26.1         1831.9     red        red              23
# 4527628313         24.7         1529.8     red       blue              10
# 4523772935         20.1         1533.9    blue       blue              16
#
#             redFinalWards  blueMinionsKilledOutsideJungle  \
# gameId
# 4519157822             13                             159
# 4523371949             11                             131
# 4521474530             15                             140
# 4524384067             14                             146
# 4436033771             13                             153
# ...                   ...                             ...
# 4527873286             44                             142
# 4527797466             12                             185
# 4527713716             13                             165
# 4527628313             62                             176
# 4523772935              9                             163
#
#             redMinionsKilledOutsideJungle
# gameId
# 4519157822                            142
# 4523371949                            188
# 4521474530                            175
# 4524384067                            188
# 4436033771                            158
# ...                                   ...
# 4527873286                            195
# 4527797466                            150
# 4527713716                            201
# 4527628313                            207
# 4523772935                            155
#
# [9879 rows x 41 columns]

# %% [markdown]
# ## Task 5
#
# `[0.8]` Create a new variable `lol_data_group` where you groupby `whoWon` and `firstKill`, with the following aggregations:
#
# - `blueTotalGold` - sum
# - `redTotalGold` -  sum
# - `blueKills` - mean
# - `redKills` - mean
# - `blueGoldPerMin` - max
# - `redGoldPerMin` - min

# %%
# Your code here
lol_data_group = lol_data.groupby(['whoWon', 'firstKill']).agg({
    'blueTotalGold': ['sum'],
    'redTotalGold': ['sum'],
    'blueKills': ['mean'],
    'redKills': ['mean'],
    'blueGoldPerMin': ['max'],
    'redGoldPerMin': ['min']})
lol_data_group.head(4)
# Out:
#                  blueTotalGold redTotalGold blueKills  redKills  \
#                            sum          sum      mean      mean
# whoWon firstKill
# blue   blue           52052931     46593556  7.682290  4.689990
#        red            32473220     31667955  6.462687  5.832733
# red    blue           32616328     33417347  5.949500  6.503500
#        red            45895158     51216382  4.641573  7.556799
#
#                  blueGoldPerMin redGoldPerMin
#                             max           min
# whoWon firstKill
# blue   blue              2370.1        1121.2
#        red               2327.8        1317.3
# red    blue              2105.5        1289.1
#        red               2088.7        1378.9

# %% [markdown]
# `[0.2]` **Rename** (use good function here) the columns of `lol_data_group` to `blueTotalGoldSum`, `redTotalGoldSum`, `blueKillsMean`, `redKillsMean`, `blueGoldPerMinMax`, `redGoldPerMinMin`.

# %%
# Your code here
lol_data_group.rename(columns={"blueTotalGold": "blueTotalGoldSum", "redTotalGold": "redTotalGoldSum" , "blueKills": "blueKillsSum" , "redKills": "redKillsSum" , "blueGoldPerMin": "blueGoldPerMinSum" , "redGoldPerMin": "redGoldPerMinSum"})
# Out:
#                  blueTotalGoldSum redTotalGoldSum blueKillsSum redKillsSum  \
#                               sum             sum         mean        mean
# whoWon firstKill
# blue   blue              52052931        46593556     7.682290    4.689990
#        red               32473220        31667955     6.462687    5.832733
# red    blue              32616328        33417347     5.949500    6.503500
#        red               45895158        51216382     4.641573    7.556799
#
#                  blueGoldPerMinSum redGoldPerMinSum
#                                max              min
# whoWon firstKill
# blue   blue                 2370.1           1121.2
#        red                  2327.8           1317.3
# red    blue                 2105.5           1289.1
#        red                  2088.7           1378.9

# %% [markdown]
# ## Task 6
#
# `[1.0]` Melt the DataFrame where the id variables are the index and value vars are `blueHeralds`, `redHeralds`, `blueDragons`, `redDragons`, `blueEliteMonsters` and `redEliteMonsters`. Save the result as `lol_data_melt`.
#
# *Hint: you can use `reset_index()` to achieve a correct melt.*

# %%
# Your code here

# %% [markdown]
# ## Task 7
#
# `[1.0]` Create a seaborn `barplot` of the `lol_data_melt` where `x` is the variable, and `y` is the value.

# %%
# Your code here
#sns.barplot(x="variable", y="value", data=lol_data_melt)

# %% [markdown]
# ## Task 8
#
# `[1.0]` Create a seaborn `scatterplot` of `lol_data`.
#
# - For `x` select `blueGoldPerMin`,
# - For `y` select `redGoldPerMin`,
# - Color the graph by `whoWon`,
# - Change dots to be different based on `firstKill` (dots and crosses).

# %%
# Your code here
sns.scatterplot(x = "blueGoldPerMin", y = "redGoldPerMin", hue = 'whoWon', style = 'firstKill', data = lol_data)

# %% [markdown]
# ## Task 9
#
# `[0.5]` Create a horizontal `matplotlib` subplot that holds two distribution plots using seaborn for `lol_data`: `redCSPerMin` and `blueCSPerMin`.

# %%
# Your code here
fig, x = plt.subplots(2, 0)
x[0] = sns.lineplot(x = 'redCSPerMin', y = 'blueCSPerMin', data = lol_data)
x[1] = sns.lineplot(x = 'blueCSPerMin', y = 'redCSPerMin', data = lol_data)

# %% [markdown]
# `[0.5]` Create a seaborn `boxplot` using `lol_data` for the `blueAvgLevel` column depending on `whoWon`.

# %%
# Your code here
sns.boxplot(x = "whoWon", y = "blueAvgLevel", data = lol_data)

# %% [markdown]
# ## Task 10
#
# `[1.0]` Create a triangle (half square) seaborn `clustermap` of the `lol_data` correlations.
#
# - Change the color palette to "mako"
#
# *Hint: You can check stack overflow how to create masks using `numpy`.*

# %%
# Your code here
sns.clustermap(lol_data.corr(), cmap="mako", linewidths=.5)
